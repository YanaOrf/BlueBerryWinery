# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as stats

# %%
red_wine=pd.read_csv("./Data_Set/winequality-red.csv",sep=";")
white_wine=pd.read_csv("./Data_Set/winequality-white.csv",sep=";")

# %%
red_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
white_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
# **# NEW COLUMN**

# %%
red_wine2=red_wine.assign(wine_color="red")
red_wine2.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
red_wine2["quality_label"]=red_wine2["quality"].apply(lambda value:"low" if value <=5 else "medium"
if value <=7 else "high" )
red_wine2.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality wine_color quality_label
# ...

# %%
white_wine2=white_wine.assign(wine_color="white")
white_wine2.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
white_wine2["quality_label"]=white_wine2["quality"].apply(lambda value: "low" if value<=5 else "medium"
if value<=7 else "high")
white_wine2.head(4)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality wine_color quality_label
# 0      8.8        6      white        medium
# 1      9.5        6      white        medium
# 2     10.1        6      white        medium
# 3      9.9        6      white        medium

# %% [markdown]
# **Concat**

# %%
wines=pd.concat([red_wine2,white_wine2])
wines.shape
# Out:
# (6497, 14)

# %% [markdown]
# **DATA CLEANING**

# %%
wines.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# wine_color              0
# dtype: int64

# %%
wines.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# wine_color              0
# quality_label           0
# dtype: int64

# %%
wines.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
wines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6497 entries, 0 to 4897
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  wine_color            6497 non-null   object
#  13  quality_label         6497 non-null   object
# dtypes: float64(11), int64(1), object(2)
# ...

# %%
wines.rename(columns={"fixed acidity":"fixed_acidity","volatile acidity":"volatile_acidity","citric acid":"citric_acid","residual sugar":"residual_sugar","free sulfur dioxide":"free_sulfur_dioxide","total sulfur dioxide":"total_sulfur_dioxide"},inplace=True)

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**

# %%
red_wine2.describe(include=["fixed_acidity","volatile_acidity"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/Yanaorfin/Documents/Academy/BlueBerryWinery/BlueBerryWinery.ipynb Cell 21 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/Yanaorfin/Documents/Academy/BlueBerryWinery/BlueBerryWinery.ipynb#X63sZmlsZQ%3D%3D?line=0'>1</a> red_wine2.describe(include=["fixed_acidity","volatile_acidity"])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:10225, in NDFrame.describe(self, percentiles, include, exclude, datetime_is_numeric)
#    9976 @final
#    9977 def describe(
#    9978     self: NDFrameT,
#    (...)
#    9982     datetime_is_numeric=False,
#    9983 ) -> NDFrameT:
#    9984     """
#    9985     Generate descriptive statistics.
#    9986
#    (...)
#   10223     max            NaN      3.0
#   10224     """
# > 10225     return describe_ndframe(
#   10226         obj=self,
# ...

# %%
pd.concat([red_wine2.describe(),white_wine2.describe()],axis=1,keys=["Red wine statistics","white wine statistics"])
# Out:
#       Red wine statistics                                               \
#             fixed acidity volatile acidity  citric acid residual sugar
# count         1599.000000      1599.000000  1599.000000    1599.000000
# mean             8.319637         0.527821     0.270976       2.538806
# std              1.741096         0.179060     0.194801       1.409928
# min              4.600000         0.120000     0.000000       0.900000
# 25%              7.100000         0.390000     0.090000       1.900000
# 50%              7.900000         0.520000     0.260000       2.200000
# 75%              9.200000         0.640000     0.420000       2.600000
# max             15.900000         1.580000     1.000000      15.500000
#
#                                                                           \
#          chlorides free sulfur dioxide total sulfur dioxide      density
# count  1599.000000         1599.000000          1599.000000  1599.000000
# ...

# %%
#quality wines

plt.title("Quality distribution of wines")
plt.xlabel("Quality")
plt.ylabel("Total wines")
plt.style.use("dark_background")
plt.hist(wines["quality"],bins=5,edgecolor="grey")
plt.show()
#color="red",bins=10 "fivethirtyeight"

print("mean - ",stats.mean(wines["quality"]))
print("median - ",stats.median(wines["quality"]))
print("mode - ",stats.mode(wines["quality"]))
print("standart_deviation - ",stats.stdev(wines["quality"]))
print("skewness - ",wines["quality"].skew())
print("max quality - ",np.max(wines["quality"]))
print("min quality - ",np.min(wines["quality"]))
# Out:
# mean -  5.818377712790519
# median -  6
# mode -  6
# standart_deviation -  0.8732552715311247
# skewness -  0.18962269337269683
# max quality -  9
# min quality -  3

# %%
sns.histplot(data=wines["quality"],x=wines["quality"],color='lightgreen',edgecolor='grey', linewidth=0.5)
# Out:
# /Users/Yanaorfin/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1057: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   comp_col.loc[orig.index] = pd.to_numeric(axis.convert_units(orig))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/Yanaorfin/Documents/Academy/BlueBerryWinery/BlueBerryWinery.ipynb Cell 25 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/Yanaorfin/Documents/Academy/BlueBerryWinery/BlueBerryWinery.ipynb#X62sZmlsZQ%3D%3D?line=0'>1</a> sns.histplot(data=wines["quality"],x=wines["quality"],color='lightgreen',edgecolor='grey', linewidth=0.5)
#
# ...

# %%
sns.boxplot(data=wines,x="alcohol",y="quality",)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='quality'>

# %%
wines["wine_color"].count()
# Out:
# 6497

# %%
plt.title("wine structure")
#plt.style.use("dark_background")
slices=wines["quality_label"]
#labels=wines["quality_label"]
plt.pie(slices)
plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/Yanaorfin/Documents/Academy/BlueBerryWinery/BlueBerryWinery.ipynb Cell 24 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/Yanaorfin/Documents/Academy/BlueBerryWinery/BlueBerryWinery.ipynb#X52sZmlsZQ%3D%3D?line=2'>3</a> slices=wines["quality_label"]
#       <a href='vscode-notebook-cell:/Users/Yanaorfin/Documents/Academy/BlueBerryWinery/BlueBerryWinery.ipynb#X52sZmlsZQ%3D%3D?line=3'>4</a> #labels=wines["quality_label"]
# ----> <a href='vscode-notebook-cell:/Users/Yanaorfin/Documents/Academy/BlueBerryWinery/BlueBerryWinery.ipynb#X52sZmlsZQ%3D%3D?line=4'>5</a> plt.pie(slices)
#       <a href='vscode-notebook-cell:/Users/Yanaorfin/Documents/Academy/BlueBerryWinery/BlueBerryWinery.ipynb#X52sZmlsZQ%3D%3D?line=5'>6</a> plt.tight_layout()
# ...
